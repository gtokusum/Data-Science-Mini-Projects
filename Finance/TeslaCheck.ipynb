# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from pandas_datareader import data, wb
# %matplotlib inline

# %%
TSLA = data.DataReader('TSLA','stooq')

# %%
TSLA.head()
# Out:
#               Open      High       Low   Close    Volume
# Date
# 2021-01-22  834.31  848.0000  828.6200  846.64  20066497
# 2021-01-21  855.00  855.7199  841.4201  844.99  20598133
# 2021-01-20  858.74  859.5000  837.2800  850.45  25665883
# 2021-01-19  837.80  850.0000  833.0000  844.55  25366980
# 2021-01-15  852.00  859.9000  819.1000  826.16  38777596

# %%
TSLA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2021-01-22 to 2016-01-25
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1259 non-null   float64
#  1   High    1259 non-null   float64
#  2   Low     1259 non-null   float64
#  3   Close   1259 non-null   float64
#  4   Volume  1259 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 91.3 KB

# %%
TSLA['Volume'].plot.line()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
TSLA[['Open','High','Low','Close']].plot.line()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
AAPL = data.DataReader('AAPL','stooq')

# %%
AAPL.head()
# Out:
#               Open      High      Low   Close     Volume
# Date
# 2021-01-22  136.28  139.8500  135.020  139.07  114459360
# 2021-01-21  133.80  139.6700  133.590  136.87  120529544
# 2021-01-20  128.66  132.4900  128.550  132.03  104319489
# 2021-01-19  127.78  128.7100  126.938  127.83   90757329
# 2021-01-15  128.78  130.2242  127.000  127.14  111598531

# %%
AAPL['Volume'].plot.line()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
AAPL[['Open','High','Low','Close']].plot.line()
# Out:
# <AxesSubplot:xlabel='Date'>
